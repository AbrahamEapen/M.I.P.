# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Meteorite Value.csv",error_bad_lines=False)
data["classification"] = data["classification"].str.lower()
data
# Out:
#       classification rarity       low      high avg_price
# 0               cil      R     128.00    1650.0    889.00
# 1                ci2      R    200.00    1000.0    600.00
# 2               cm1       R       NA        NaN       NaN
# 3               cm2     VC       4.00     100.0     52.00
# 4               cr2      C      25.00     200.0    112.50
# 5               ch3      R      50.00     500.0    275.00
# 6                cb       C     10.00       NaN     10.00
# 7               co3      VC      3.00     100.0     51.50
# 8               ck3       R      100        NaN    100.00
# 9               ck4       C     10.00     100.0     55.00
# 10              ck5       R     20.00     150.0     85.00
# 11              ck6       R       NA        NaN       NaN
# 12               cv3    VC       2.00     200.0    101.00
# 13              cv4       R       NA        NaN       NaN
# 14                c4      R     25.00     150.0     87.50
# ...
