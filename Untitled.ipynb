# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Meteorite Value.csv", dtype={'high':int, 'low':int}, na_values=str)
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-3d8309f8f4bc> in <module>()
# ----> 1 data = pd.read_csv("Meteorite Value.csv", dtype={'high':int, 'low':int}, na_values=str)
#       2 data.head()
#
# ...

# %%
new = data[["low","high"]].apply(pd.to_numeric, errors="ignore")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e945bccf5068> in <module>()
# ----> 1 new = data[["low","high"]].apply(pd.to_numeric, errors="ignore")
#
# NameError: name 'data' is not defined

# %%
# Out:
#       classification            price rarity         low      high  \
# 0               CIl        128-1,650      R      128.00     1,650
# 1                CI2       200-1,000       R     200.00     1,000
# 2               CM1               NA       R         NA        NaN
# 3               CM2            4-100     VC        4.00       100
# 4               CR2           25-200      C       25.00       200
# 5               CH3           50-500      R       50.00       500
# 6                CB           10-350       C      10.00       350
# 7               CO3            3-100      VC       3.00       100
# 8               CK3              100       R        100        NaN
# 9               CK4           10-100       C      10.00       100
# 10              CK5           20-150       R      20.00       150
# 11              CK6               NA       R         NA        NaN
# 12               CV3           2-200     VC        2.00       200
# ...

# %%
# Out:
#       classification            price rarity         low      high  \
# 0               CIl        128-1,650      R      128.00     1,650
# 1                CI2       200-1,000       R     200.00     1,000
# 2               CM1               NA       R         NA        NaN
# 3               CM2            4-100     VC        4.00       100
# 4               CR2           25-200      C       25.00       200
# 5               CH3           50-500      R       50.00       500
# 6                CB           10-350       C      10.00       350
# 7               CO3            3-100      VC       3.00       100
# 8               CK3              100       R        100        NaN
# 9               CK4           10-100       C      10.00       100
# 10              CK5           20-150       R      20.00       150
# 11              CK6               NA       R         NA        NaN
# 12               CV3           2-200     VC        2.00       200
# ...
